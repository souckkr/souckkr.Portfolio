# %% [markdown]
# ## 형태소 분석기 공통 메소드
# - `morphs(string)` : 형태소 단위로 토큰화(tokenize)
# - `nouns(string)` : 명사만 추출하여 토큰화(tokenize)
# - `pos(string)`: 품사 부착
#     - 형태소 분석기 마다 사용하는 품사태그가 다르다.
#         - https://konlpy-ko.readthedocs.io/ko/v0.5.2/morph/
# - `tagset`: 형태소 분석기가 사용하는 품사태그 설명하는 속성.

# %%
txt = "전세 낀 매물의 매매계약 단계에서 현 세입자의 동의가 있으면 새 집주인(매수인)도 실거주할 수 있다는 유권 해석이 나왔다. 매수인은 소유권이전등기 전까진 세입자가 계약갱신청구권을 행사하거나 이를 거절할 수 있는 대상은 아니지만, 매매계약의 안정성을 보장하기 위해 이를 허용한다는 취지다."

# %%
from konlpy.tag import Okt

# Open Korea Text 형태소 분석기 
okt = Okt()
# 형태소 추출
okt_tokens = okt.morphs(txt)
len(okt_tokens)
# Out:
# 74

# %%
print(okt_tokens)
# Out:
# ['전세', '낀', '매물', '의', '매매', '계약', '단계', '에서', '현', '세', '입자', '의', '동의', '가', '있으면', '새', '집주인', '(', '매수', '인', ')', '도', '실', '거주', '할', '수', '있다는', '유권', '해석', '이', '나왔다', '.', '매', '수인', '은', '소유권', '이전', '등기', '전', '까진', '세', '입자', '가', '계약', '갱신', '청구권', '을', '행사', '하', '거나', '이를', '거절', '할', '수', '있는', '대상', '은', '아니지만', ',', '매매', '계약', '의', '안정', '성', '을', '보장', '하기', '위해', '이를', '허용', '한다는', '취지', '다', '.']

# %%
okt_tokens2 = okt.morphs(txt, stem=True) #stem=True: 원본복원 (Okt의 옵션)
print(okt_tokens2)
# Out:
# ['전세', '끼다', '매물', '의', '매매', '계약', '단계', '에서', '현', '세', '입자', '의', '동의', '가', '있다', '새', '집주인', '(', '매수', '인', ')', '도', '실', '거주', '하다', '수', '있다', '유권', '해석', '이', '나오다', '.', '매', '수인', '은', '소유권', '이전', '등기', '전', '까진', '세', '입자', '가', '계약', '갱신', '청구권', '을', '행사', '하', '거나', '이르다', '거절', '하다', '수', '있다', '대상', '은', '아니다', ',', '매매', '계약', '의', '안정', '성', '을', '보장', '하다', '위해', '이르다', '허용', '한다는', '취지', '다', '.']

# %%
okt_nouns = okt.nouns(txt) #명사만 추출
len(okt_nouns)
# Out:
# 38

# %%
print(okt_nouns)
# Out:
# ['전세', '매물', '매매', '계약', '단계', '현', '입자', '동의', '새', '집주인', '매수', '도', '실', '거주', '수', '유권', '해석', '수인', '소유권', '이전', '등기', '전', '입자', '계약', '갱신', '청구권', '행사', '거나', '거절', '수', '대상', '매매', '계약', '안정', '보장', '위해', '허용', '취지']

# %%
pos_tokens = okt.pos(txt)
print(pos_tokens)
# Out:
# [('전세', 'Noun'), ('낀', 'Verb'), ('매물', 'Noun'), ('의', 'Josa'), ('매매', 'Noun'), ('계약', 'Noun'), ('단계', 'Noun'), ('에서', 'Josa'), ('현', 'Noun'), ('세', 'Modifier'), ('입자', 'Noun'), ('의', 'Josa'), ('동의', 'Noun'), ('가', 'Josa'), ('있으면', 'Adjective'), ('새', 'Noun'), ('집주인', 'Noun'), ('(', 'Punctuation'), ('매수', 'Noun'), ('인', 'Josa'), (')', 'Punctuation'), ('도', 'Noun'), ('실', 'Noun'), ('거주', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있다는', 'Adjective'), ('유권', 'Noun'), ('해석', 'Noun'), ('이', 'Josa'), ('나왔다', 'Verb'), ('.', 'Punctuation'), ('매', 'Modifier'), ('수인', 'Noun'), ('은', 'Josa'), ('소유권', 'Noun'), ('이전', 'Noun'), ('등기', 'Noun'), ('전', 'Noun'), ('까진', 'Josa'), ('세', 'Modifier'), ('입자', 'Noun'), ('가', 'Josa'), ('계약', 'Noun'), ('갱신', 'Noun'), ('청구권', 'Noun'), ('을', 'Josa'), ('행사', 'Noun'), ('하', 'Suffix'), ('거나', 'Noun'), ('이를', 'Verb'), ('거절', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('대상', 'Noun'), ('은', 'Josa'), ('아니지만', 'Adjective'), (',', 'Punctuation'), ('매매', 'Noun'), ('계약', 'Noun'), ('의', 'Josa'), ('안정', 'Noun'), ('성', 'Suffix'), ('을', 'Josa'), ('보장', 'Noun'), ('하기', 'Verb'), ('위해', 'Noun'), ('이를', 'Verb'), ('허용', 'Noun'), ('한다는', 'Modifier'), ('취지', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation')]

# %%
pos_token2 = okt.pos(txt, join=True) #'형태소/품사'
print(pos_token2)
# Out:
# ['전세/Noun', '낀/Verb', '매물/Noun', '의/Josa', '매매/Noun', '계약/Noun', '단계/Noun', '에서/Josa', '현/Noun', '세/Modifier', '입자/Noun', '의/Josa', '동의/Noun', '가/Josa', '있으면/Adjective', '새/Noun', '집주인/Noun', '(/Punctuation', '매수/Noun', '인/Josa', ')/Punctuation', '도/Noun', '실/Noun', '거주/Noun', '할/Verb', '수/Noun', '있다는/Adjective', '유권/Noun', '해석/Noun', '이/Josa', '나왔다/Verb', './Punctuation', '매/Modifier', '수인/Noun', '은/Josa', '소유권/Noun', '이전/Noun', '등기/Noun', '전/Noun', '까진/Josa', '세/Modifier', '입자/Noun', '가/Josa', '계약/Noun', '갱신/Noun', '청구권/Noun', '을/Josa', '행사/Noun', '하/Suffix', '거나/Noun', '이를/Verb', '거절/Noun', '할/Verb', '수/Noun', '있는/Adjective', '대상/Noun', '은/Josa', '아니지만/Adjective', ',/Punctuation', '매매/Noun', '계약/Noun', '의/Josa', '안정/Noun', '성/Suffix', '을/Josa', '보장/Noun', '하기/Verb', '위해/Noun', '이를/Verb', '허용/Noun', '한다는/Modifier', '취지/Noun', '다/Josa', './Punctuation']

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
txt = "이것도 되나욬ㅋㅋㅋㅋ"
okt.morphs(txt)
# Out:
# ['이', '것', '도', '되나욬', 'ㅋㅋㅋㅋ']

# %%
okt.morphs(txt, norm=True) #norm=True :  SNS상의 비속어들을 처리해준다. (OKT의 기능)
# Out:
# ['이', '것', '도', '되나요', 'ㅋㅋㅋ']

# %%
okt.normalize(txt), okt.normalize('반갑습니당') # OKT의 기능
# Out:
# ('이것도 되나요ㅋㅋㅋ', '반갑습니다')

# %%
txt = "전세 낀 매물의 매매계약 단계에서 현 세입자의 동의가 있으면 새 집주인(매수인)도 실거주할 수 있다는 유권 해석이 나왔다. 매수인은 소유권이전등기 전까진 세입자가 계약갱신청구권을 행사하거나 이를 거절할 수 있는 대상은 아니지만, 매매계약의 안정성을 보장하기 위해 이를 허용한다는 취지다."

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
ko_tokens = komoran.morphs(txt)
len(ko_tokens)
# Out:
# 84

# %%
print(ko_tokens)
# Out:
# ['전세', '끼', 'ㄴ', '매물', '의', '매매', '계약', '단계', '에서', '현', '세입자', '의', '동의', '가', '있', '으면', '새', '집주인', '(', '매수인', ')', '도', '실', '거주', '하', 'ㄹ', '수', '있', '다는', '유권 해석', '이', '나오', '았', '다', '.', '매수인', '은', '소유권', '이전', '등기', '전', '까지', 'ㄴ', '세입자', '가', '계약', '갱신', '청구권', '을', '행사', '하', '거나', '이', '를', '거절', '하', 'ㄹ', '수', '있', '는', '대상', '은', '아니', '지만', ',', '매매', '계약', '의', '안정', '성', '을', '보장', '하', '기', '위하', '아', '이', '를', '허용', '하', 'ㄴ다는', '취지', '다', '.']

# %%
print(okt.morphs(txt, stem=True))
# Out:
# ['전세', '끼다', '매물', '의', '매매', '계약', '단계', '에서', '현', '세', '입자', '의', '동의', '가', '있다', '새', '집주인', '(', '매수', '인', ')', '도', '실', '거주', '하다', '수', '있다', '유권', '해석', '이', '나오다', '.', '매', '수인', '은', '소유권', '이전', '등기', '전', '까진', '세', '입자', '가', '계약', '갱신', '청구권', '을', '행사', '하', '거나', '이르다', '거절', '하다', '수', '있다', '대상', '은', '아니다', ',', '매매', '계약', '의', '안정', '성', '을', '보장', '하다', '위해', '이르다', '허용', '한다는', '취지', '다', '.']

# %%
komoran.morphs(txt, norm=True) #stem, norm 매개변수는 OKT만의 기능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-66c656bef46d> in <module>
# ----> 1 komoran.morphs(txt, norm=True)
#
# TypeError: morphs() got an unexpected keyword argument 'norm'

# %%
ko_nouns = komoran.nouns(txt)
len(ko_nouns)
# Out:
# 32

# %%
print(ko_nouns)
# Out:
# ['전세', '매물', '매매', '계약', '단계', '세입자', '동의', '집주인', '매수인', '실', '거주', '수', '유권 해석', '매수인', '소유권', '이전', '등기', '전', '세입자', '계약', '갱신', '청구권', '행사', '거절', '수', '대상', '매매', '계약', '안정', '보장', '허용', '취지']

# %%
ko_tag = komoran.pos(txt)
print(ko_tag)
# Out:
# [('전세', 'NNG'), ('끼', 'VV'), ('ㄴ', 'ETM'), ('매물', 'NNG'), ('의', 'JKG'), ('매매', 'NNP'), ('계약', 'NNP'), ('단계', 'NNG'), ('에서', 'JKB'), ('현', 'MM'), ('세입자', 'NNG'), ('의', 'JKG'), ('동의', 'NNG'), ('가', 'JKS'), ('있', 'VV'), ('으면', 'EC'), ('새', 'MM'), ('집주인', 'NNG'), ('(', 'SS'), ('매수인', 'NNG'), (')', 'SS'), ('도', 'JX'), ('실', 'NNG'), ('거주', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('수', 'NNB'), ('있', 'VV'), ('다는', 'ETM'), ('유권 해석', 'NNP'), ('이', 'JKS'), ('나오', 'VV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF'), ('매수인', 'NNG'), ('은', 'JX'), ('소유권', 'NNP'), ('이전', 'NNP'), ('등기', 'NNP'), ('전', 'NNG'), ('까지', 'JX'), ('ㄴ', 'JX'), ('세입자', 'NNG'), ('가', 'JKS'), ('계약', 'NNG'), ('갱신', 'NNG'), ('청구권', 'NNP'), ('을', 'JKO'), ('행사', 'NNG'), ('하', 'XSV'), ('거나', 'EC'), ('이', 'NP'), ('를', 'JKO'), ('거절', 'NNG'), ('하', 'XSV'), ('ㄹ', 'ETM'), ('수', 'NNB'), ('있', 'VV'), ('는', 'ETM'), ('대상', 'NNG'), ('은', 'JX'), ('아니', 'VCN'), ('지만', 'EC'), (',', 'SP'), ('매매', 'NNP'), ('계약', 'NNP'), ('의', 'JKG'), ('안정', 'NNG'), ('성', 'XSN'), ('을', 'JKO'), ('보장', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('위하', 'VV'), ('아', 'EC'), ('이', 'NP'), ('를', 'JKO'), ('허용', 'NNG'), ('하', 'XSV'), ('ㄴ다는', 'ETM'), ('취지', 'NNG'), ('다', 'JX'), ('.', 'SF')]

# %%
print(komoran.pos(txt, join=True))
# Out:
# ['전세/NNG', '끼/VV', 'ㄴ/ETM', '매물/NNG', '의/JKG', '매매/NNP', '계약/NNP', '단계/NNG', '에서/JKB', '현/MM', '세입자/NNG', '의/JKG', '동의/NNG', '가/JKS', '있/VV', '으면/EC', '새/MM', '집주인/NNG', '(/SS', '매수인/NNG', ')/SS', '도/JX', '실/NNG', '거주/NNG', '하/XSV', 'ㄹ/ETM', '수/NNB', '있/VV', '다는/ETM', '유권 해석/NNP', '이/JKS', '나오/VV', '았/EP', '다/EF', './SF', '매수인/NNG', '은/JX', '소유권/NNP', '이전/NNP', '등기/NNP', '전/NNG', '까지/JX', 'ㄴ/JX', '세입자/NNG', '가/JKS', '계약/NNG', '갱신/NNG', '청구권/NNP', '을/JKO', '행사/NNG', '하/XSV', '거나/EC', '이/NP', '를/JKO', '거절/NNG', '하/XSV', 'ㄹ/ETM', '수/NNB', '있/VV', '는/ETM', '대상/NNG', '은/JX', '아니/VCN', '지만/EC', ',/SP', '매매/NNP', '계약/NNP', '의/JKG', '안정/NNG', '성/XSN', '을/JKO', '보장/NNG', '하/XSV', '기/ETN', '위하/VV', '아/EC', '이/NP', '를/JKO', '허용/NNG', '하/XSV', 'ㄴ다는/ETM', '취지/NNG', '다/JX', './SF']

# %%
komoran.tagset
# Out:
# {'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ETM': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JKB': '부사격 조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JKV': '호격 조사',
#  'JX': '보조사',
#  'MAG': '일반 부사',
#  'MAJ': '접속 부사',
#  'MM': '관형사',
#  'NA': '분석불능범주',
#  'NF': '명사추정범주',
#  'NNB': '의존 명사',
#  'NNG': '일반 명사',
#  'NNP': '고유 명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'NV': '용언추정범주',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SH': '한자',
#  'SL': '외국어',
#  'SN': '숫자',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'VA': '형용사',
#  'VCN': '부정 지정사',
#  'VCP': '긍정 지정사',
#  'VV': '동사',
#  'VX': '보조 용언',
#  'XPN': '체언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %% [markdown]
# # KoNLPy 형태소 분석기와 NLTK를 이용한 문서의 분석

# %%
from nltk import Text
from konlpy.corpus import kolaw
from konlpy.tag import Komoran

# %%
law_txt = kolaw.open('constitution.txt').read()

# %%
law_txt[:200]
# Out:
# '대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제'

# %%
# 명사만 추출
komoran = Komoran()
nouns = komoran.adj(law_txt)
len(nouns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-126461699d56> in <module>
#       1 # 명사만 추출
#       2 komoran = Komoran()
# ----> 3 nouns = komoran.adj(law_txt)
#       4 len(nouns)
#
# AttributeError: 'Komoran' object has no attribute 'adj'

# %%
# 명사만 추출
komoran = Komoran()
nouns = komoran.nouns(law_txt)
len(nouns)
# Out:
# 3358

# %%
print(nouns[:20])
# Out:
# ['대한민국', '헌법', '역사', '전통', '국민', '운동', '건립', '대한민국', '임시', '정부', '법통', '불의', '항거', '민주', '이념', '계승', '조국', '민주개혁', '평화', '통일']

# %%
# 2글자 이상인 단어들만 추출
nouns = [noun for noun in nouns if len(noun)>=2]
len(nouns)
# Out:
# 2973

# %%
text = Text(nouns, name='대한민국 헌법')
text
# Out:
# <Text: 대한민국 헌법>

# %%
print('"대한민국" 빈도수', text.count('대한민국'))
print('"헌법" 빈도수', text.count('헌법'))
print('"국민" 빈도수', text.count('국민'))
# Out:
# "대한민국" 빈도수 10
# "헌법" 빈도수 55
# "국민" 빈도수 67

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))

plt.title('헌법에 나온 명사 빈도수')
text.plot(20) #빈도수 상위 20개 단어를 선그래프로 그린다.
plt.show()

# %%
plt.figure(figsize=(15,7))
text.dispersion_plot(['법률','대통령','국가','국회', '국민'])

# %%
# 매개변수로 전달한 단어가 나온 문장 조회
text.concordance('국민', width=50, lines=10) #width-글자수, lines- 라인수
# Out:
# Displaying 10 of 67 matches:
# 대한민국 헌법 역사 전통 국민 운동 건립 대한민국 임시 정부 법통 불의
# 최고 도로 발휘 자유 권리 책임 의무 완수 국민 생활 균등 향상 항구 세계 평화 인류 공영
# 짐 7월 12일 제정 개정 헌법 국회 의결 국민 투표 개정 대한민국 민주공화국 대한민국 주
# 표 개정 대한민국 민주공화국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가
# 한민국 민주공화국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가 법률 재외국
# 국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가 법률 재외국민 보호 의무
# 효력 외국인 국제법 조약 지위 보장 공무원 국민 전체 봉사자 국민 책임 공무원 신분 정치
#  조약 지위 보장 공무원 국민 전체 봉사자 국민 책임 공무원 신분 정치 중립 법률 보장 정
# 복수 정당 보장 정당 목적 조직 활동 민주 국민 정치 의사 형성 참여 필요 조직 정당 법률
#  민족 문화 창달 노력 국민의 권리와 의무 국민 인간 존엄 가치 행복 추구 권리 국가 개인

# %%
#FreqDist를 이용해 빈도수 관련 정보 확인
fd = text.vocab()
fd
# Out:
# FreqDist({'법률': 128, '대통령': 84, '국가': 70, '국회': 69, '국민': 67, '헌법': 55, '필요': 30, '기타': 26, '사항': 23, '법관': 22, ...})

# %%
print('총 고유단어 개수:', fd.B())
print('총 토큰(단어)의 개수', fd.N())
print('최빈 단어-가장 많이 나온 단어:', fd.max())
print('최빈 단어의 빈도수:', fd.get(fd.max()))
print('총토큰수 대비 최빈단어의 비율:', fd.freq(fd.max()))
# Out:
# 총 고유단어 개수: 834
# 총 토큰(단어)의 개수 2973
# 최빈 단어-가장 많이 나온 단어: 법률
# 최빈 단어의 빈도수: 128
# 총토큰수 대비 최빈단어의 비율: 0.04305415405314497

# %%
word_cnt = fd.most_common()
word_cnt
# Out:
# [('법률', 128),
#  ('대통령', 84),
#  ('국가', 70),
#  ('국회', 69),
#  ('국민', 67),
#  ('헌법', 55),
#  ('필요', 30),
#  ('기타', 26),
#  ('사항', 23),
#  ('법관', 22),
#  ('보장', 21),
#  ('정부', 20),
#  ('국회의원', 20),
#  ('경제', 19),
#  ('직무', 19),
#  ('선거', 19),
#  ('국무총리', 19),
#  ('임명', 19),
#  ('의무', 18),
#  ('조직', 18),
#  ('임기', 18),
#  ('권리', 17),
#  ('의결', 17),
#  ('공무원', 17),
#  ('경우', 17),
#  ('이상', 17),
#  ('의원', 17),
#  ('국무위원', 17),
#  ('자유', 15),
#  ('정당', 15),
#  ('항의', 15),
#  ('보호', 14),
#  ('정책', 14),
#  ('헌법재판소', 14),
#  ('노력', 13),
#  ('법원', 13),
#  ('요구', 13),
#  ('집회', 12),
#  ('출석', 12),
#  ('찬성', 12),
#  ('조약', 11),
#  ('동의', 11),
#  ('과반수', 11),
#  ('행정', 11),
#  ('탄핵', 11),
#  ('대한민국', 10),
#  ('공포', 10),
#  ('심판', 10),
#  ('재판', 10),
#  ('처분', 10),
#  ('교육', 10),
#  ('시행', 10),
#  ('재적', 10),
#  ('위원', 10),
#  ('권한', 10),
#  ('자문', 10),
#  ('대법원', 10),
#  ('사회', 9),
#  ('기본', 9),
#  ('정치', 9),
#  ('개정', 9),
#  ('효력', 9),
#  ('체포', 9),
#  ('절차', 9),
#  ('형사', 9),
#  ('근로', 9),
#  ('회의', 9),
#  ('국정', 9),
#  ('범위', 9),
#  ('명령', 9),
#  ('지방', 9),
#  ('자치', 9),
#  ('안전', 8),
#  ('제정', 8),
#  ('투표', 8),
#  ('인정', 8),
#  ('구속', 8),
#  ('구성', 8),
#  ('확정', 8),
#  ('제출', 8),
#  ('각부', 8),
#  ('재판관', 8),
#  ('단체', 8),
#  ('대법원장', 8),
#  ('생활', 7),
#  ('수립', 7),
#  ('유지', 7),
#  ('이유', 7),
#  ('행위', 7),
#  ('제한', 7),
#  ('기관', 7),
#  ('공개', 7),
#  ('선출', 7),
#  ('3분', 7),
#  ('감사', 7),
#  ('위안', 7),
#  ('선거관리위원회', 7),
#  ('국무회의', 7),
#  ('관리', 7),
#  ('최초', 7),
#  ('평화', 6),
#  ('통일', 6),
#  ('승인', 6),
#  ('청구', 6),
#  ('피고인', 6),
#  ('지체', 6),
#  ('소추', 6),
#  ('침해', 6),
#  ('군사', 6),
#  ('재정', 6),
#  ('개발', 6),
#  ('의장', 6),
#  ('규정', 6),
#  ('이내', 6),
#  ('회계', 6),
#  ('처리', 6),
#  ('규칙', 6),
#  ('자격', 6),
#  ('감사원', 6),
#  ('결정', 6),
#  ('중임', 6),
#  ('제청', 6),
#  ('당시', 6),
#  ('민주', 5),
#  ('질서', 5),
#  ('책임', 5),
#  ('향상', 5),
#  ('운영', 5),
#  ('해산', 5),
#  ('발전', 5),
#  ('제도', 5),
#  ('진술', 5),
#  ('심사', 5),
#  ('언론', 5),
#  ('출판', 5),
#  ('내용', 5),
#  ('군인', 5),
#  ('제외', 5),
#  ('회기', 5),
#  ('기간', 5),
#  ('재의', 5),
#  ('예산안', 5),
#  ('심의', 5),
#  ('연도', 5),
#  ('개시', 5),
#  ('예산', 5),
#  ('설치', 5),
#  ('계엄', 5),
#  ('계획', 5),
#  ('개정안', 5),
#  ('각급', 5),
#  ('사무', 5),
#  ('균형', 5),
#  ('이용', 5),
#  ('육성', 5),
#  ('문화', 4),
#  ('영역', 4),
#  ('국군', 4),
#  ('수행', 4),
#  ('체결', 4),
#  ('목적', 4),
#  ('평등', 4),
#  ('검사', 4),
#  ('영장', 4),
#  ('변호인', 4),
#  ('방법', 4),
#  ('범죄', 4),
#  ('재산권', 4),
#  ('타인', 4),
#  ('보상', 4),
#  ('비상계엄', 4),
#  ('선포', 4),
#  ('군사법원', 4),
#  ('판결', 4),
#  ('집행', 4),
#  ('근로자', 4),
#  ('조건', 4),
#  ('임시회', 4),
#  ('적의', 4),
#  ('다음', 4),
#  ('지출', 4),
#  ('부담', 4),
#  ('발의', 4),
#  ('저촉', 4),
#  ('내부', 4),
#  ('규율', 4),
#  ('파면', 4),
#  ('후임자', 4),
#  ('긴급', 4),
#  ('관계', 4),
#  ('사면', 4),
#  ('원로', 4),
#  ('선고', 4),
#  ('선임', 4),
#  ('농지', 4),
#  ('운동', 3),
#  ('조국', 3),
#  ('민족', 3),
#  ('단결', 3),
#  ('자율', 3),
#  ('기회', 3),
#  ('능력', 3),
#  ('최고', 3),
#  ('균등', 3),
#  ('국제', 3),
#  ('중립', 3),
#  ('일반', 3),
#  ('지위', 3),
#  ('신분', 3),
#  ('활동', 3),
#  ('위배', 3),
#  ('제소', 3),
#  ('인간', 3),
#  ('개인', 3),
#  ('영전', 3),
#  ('압수', 3),
#  ('수색', 3),
#  ('처벌', 3),
#  ('현행범', 3),
#  ('증거', 3),
#  ('입법', 3),
#  ('주거', 3),
#  ('비밀', 3),
#  ('배상', 3),
#  ('행사', 3),
#  ('선거권', 3),
#  ('문서', 3),
#  ('청원', 3),
#  ('재판을 받을 권리', 3),
#  ('군무원', 3),
#  ('구금', 3),
#  ('공공단체', 3),
#  ('증진', 3),
#  ('단체행동권', 3),
#  ('복지', 3),
#  ('실시', 3),
#  ('사유', 3),
#  ('보전', 3),
#  ('이익', 3),
#  ('기업체', 3),
#  ('계약', 3),
#  ('만료', 3),
#  ('편성', 3),
#  ('변경', 3),
#  ('상호', 3),
#  ('강화', 3),
#  ('선전', 3),
#  ('외국', 3),
#  ('의견', 3),
#  ('정부위원', 3),
#  ('보고', 3),
#  ('해임', 3),
#  ('건의', 3),
#  ('중앙', 3),
#  ('대통령령', 3),
#  ('안녕질서', 3),
#  ('조치', 3),
#  ('해제', 3),
#  ('감형', 3),
#  ('복권', 3),
#  ('대외', 3),
#  ('결산', 3),
#  ('조정', 3),
#  ('지명', 3),
#  ('국가안전보장회의', 3),
#  ('사무에', 3),
#  ('행정기관', 3),
#  ('원장', 3),
#  ('연임', 3),
#  ('금고', 3),
#  ('여부', 3),
#  ('간의', 3),
#  ('법령', 3),
#  ('제안', 3),
#  ('불의', 2),
#  ('계승', 2),
#  ('사명', 2),
#  ('입각', 2),
#  ('조화', 2),
#  ('행복', 2),
#  ('주권', 2),
#  ('영토', 2),
#  ('준수', 2),
#  ('의사', 2),
#  ('창달', 2),
#  ('존엄', 2),
#  ('종교', 2),
#  ('차별', 2),
#  ('훈장', 2),
#  ('적법', 2),
#  ('고문', 2),
#  ('신청', 2),
#  ('발부', 2),
#  ('제시', 2),
#  ('장기', 2),
#  ('염려', 2),
#  ('조력', 2),
#  ('자백', 2),
#  ('유죄', 2),
#  ('이익한', 2),
#  ('처우', 2),
#  ('이전', 2),
#  ('통신', 2),
#  ('결사의 자유', 2),
#  ('허가', 2),
#  ('시설', 2),
#  ('기준', 2),
#  ('명예', 2),
#  ('피해자', 2),
#  ('피해', 2),
#  ('과학기술', 2),
#  ('공공복리', 2),
#  ('초병', 2),
#  ('초소', 2),
#  ('유독', 2),
#  ('음식물', 2),
#  ('공급', 2),
#  ('포로', 2),
#  ('무죄', 2),
#  ('불법행위', 2),
#  ('손해', 2),
#  ('면제', 2),
#  ('관련', 2),
#  ('신체', 2),
#  ('구조', 2),
#  ('평생', 2),
#  ('포함', 2),
#  ('고용', 2),
#  ('적정', 2),
#  ('임금', 2),
#  ('원칙', 2),
#  ('여자', 2),
#  ('군경', 2),
#  ('단체교섭', 2),
#  ('환경', 2),
#  ('이행', 2),
#  ('보통', 2),
#  ('직접', 2),
#  ('발언', 2),
#  ('양심', 2),
#  ('남용', 2),
#  ('재산', 2),
#  ('취득', 2),
#  ('정기회', 2),
#  ('인과', 2),
#  ('부의장', 2),
#  ('이송', 2),
#  ('이의', 2),
#  ('발생', 2),
#  ('경비', 2),
#  ('계속', 2),
#  ('예비비', 2),
#  ('비준', 2),
#  ('포고', 2),
#  ('파견', 2),
#  ('조사', 2),
#  ('위원회', 2),
#  ('상황', 2),
#  ('답변', 2),
#  ('독립', 2),
#  ('당선자', 2),
#  ('후보자', 2),
#  ('상실', 2),
#  ('선서', 2),
#  ('보위', 2),
#  ('복리', 2),
#  ('외교', 2),
#  ('국방', 2),
#  ('안위', 2),
#  ('위임', 2),
#  ('외환', 2),
#  ('공공', 2),
#  ('보좌', 2),
#  ('현역', 2),
#  ('이하', 2),
#  ('총장', 2),
#  ('직전', 2),
#  ('민주평화통일자문회의', 2),
#  ('세입', 2),
#  ('세출', 2),
#  ('사법', 2),
#  ('장과', 2),
#  ('위반', 2),
#  ('전제', 2),
#  ('행정심판', 2),
#  ('심리', 2),
#  ('군사재판', 2),
#  ('관할', 2),
#  ('위헌', 2),
#  ('소원', 2),
#  ('관중', 2),
#  ('가입', 2),
#  ('관여', 2),
#  ('지시', 2),
#  ('의회', 2),
#  ('기업', 2),
#  ('안정', 2),
#  ('규제', 2),
#  ('자원', 2),
#  ('국토', 2),
#  ('달성', 2),
#  ('농업', 2),
#  ('경영', 2),
#  ('지역', 2),
#  ('중소기업', 2),
#  ('어민', 2),
#  ('부칙', 2),
#  ('시행일', 2),
#  ('전일', 2),
#  ('역사', 1),
#  ('전통', 1),
#  ('건립', 1),
#  ('임시', 1),
#  ('법통', 1),
#  ('항거', 1),
#  ('이념', 1),
#  ('민주개혁', 1),
#  ('정의', 1),
#  ('인도', 1),
#  ('동포애', 1),
#  ('폐습', 1),
#  ('타파', 1),
#  ('바탕', 1),
#  ('각인', 1),
#  ('도로', 1),
#  ('발휘', 1),
#  ('완수', 1),
#  ('항구', 1),
#  ('세계', 1),
#  ('인류', 1),
#  ('공영', 1),
#  ('이바지', 1),
#  ('우리들의', 1),
#  ('자손', 1),
#  ('확보', 1),
#  ('다짐', 1),
#  ('7월 12일', 1),
#  ('민주공화국', 1),
#  ('권력', 1),
#  ('요건', 1),
#  ('재외국민', 1),
#  ('한반도', 1),
#  ('부속', 1),
#  ('도서', 1),
#  ('지향', 1),
#  ('추진', 1),
#  ('침략', 1),
#  ('전쟁', 1),
#  ('부인', 1),
#  ('국토방위', 1),
#  ('신성', 1),
#  ('법규', 1),
#  ('국내법', 1),
#  ('외국인', 1),
#  ('국제법', 1),
#  ('전체', 1),
#  ('봉사자', 1),
#  ('설립', 1),
#  ('복수', 1),
#  ('형성', 1),
#  ('참여', 1),
#  ('자금', 1),
#  ('보조', 1),
#  ('전통문화', 1),
#  ('국민의 권리와 의무', 1),
#  ('가치', 1),
#  ('추구', 1),
#  ('불가침', 1),
#  ('인권', 1),
#  ('확인', 1),
#  ('성별', 1),
#  ('특수', 1),
#  ('계급', 1),
#  ('형태', 1),
#  ('창설', 1),
#  ('특권', 1),
#  ('신체의 자유', 1),
#  ('심문', 1),
#  ('보안처분', 1),
#  ('강제', 1),
#  ('노역', 1),
#  ('강요', 1),
#  ('해당', 1),
#  ('도피', 1),
#  ('인멸', 1),
#  ('사후', 1),
#  ('고지', 1),
#  ('가족', 1),
#  ('일시', 1),
#  ('장소', 1),
#  ('통지', 1),
#  ('부의', 1),
#  ('폭행', 1),
#  ('협박', 1),
#  ('자의', 1),
#  ('정식', 1),
#  ('유일한', 1),
#  ('소급', 1),
#  ('참정권', 1),
#  ('박탈', 1),
#  ('친족', 1),
#  ('거주', 1),
#  ('직업', 1),
#  ('선택', 1),
#  ('사생활의 비밀과 자유', 1),
#  ('양심의 자유', 1),
#  ('종교의 자유', 1),
#  ('국교', 1),
#  ('분리', 1),
#  ('검열', 1),
#  ('결사', 1),
#  ('방송', 1),
#  ('신문', 1),
#  ('기능', 1),
#  ('공중도덕', 1),
#  ('윤리', 1),
#  ('학문', 1),
#  ('예술', 1),
#  ('저작자', 1),
#  ('발명가', 1),
#  ('자와', 1),
#  ('예술가', 1),
#  ('한계', 1),
#  ('공공필요', 1),
#  ('수용', 1),
#  ('사용', 1),
#  ('지급', 1),
#  ('공무담임권', 1),
#  ('기밀', 1),
#  ('군용', 1),
#  ('신속', 1),
#  ('상당', 1),
#  ('추정', 1),
#  ('사건', 1),
#  ('피의자', 1),
#  ('기소', 1),
#  ('자신', 1),
#  ('경찰', 1),
#  ('전투', 1),
#  ('훈련', 1),
#  ('생명', 1),
#  ('자녀', 1),
#  ('초등', 1),
#  ('무상', 1),
#  ('자주성', 1),
#  ('전문', 1),
#  ('대학', 1),
#  ('진흥', 1),
#  ('학교', 1),
#  ('교원', 1),
#  ('최저임금', 1),
#  ('민주주의', 1),
#  ('존엄성', 1),
#  ('연소자', 1),
#  ('유공자', 1),
#  ('유가족', 1),
#  ('우선', 1),
#  ('부여', 1),
#  ('자주', 1),
#  ('방위', 1),
#  ('산업체', 1),
#  ('종사', 1),
#  ('다운', 1),
#  ('권익', 1),
#  ('노인', 1),
#  ('청소년', 1),
#  ('장애자', 1),
#  ('질병', 1),
#  ('노령', 1),
#  ('재해', 1),
#  ('예방', 1),
#  ('위험', 1),
#  ('건강', 1),
#  ('환경권', 1),
#  ('주택', 1),
#  ('혼인', 1),
#  ('가족생활', 1),
#  ('양성', 1),
#  ('기초', 1),
#  ('성립', 1),
#  ('모성', 1),
#  ('보건', 1),
#  ('열거', 1),
#  ('경시', 1),
#  ('본질', 1),
#  ('납세', 1),
#  ('국방의 의무', 1),
#  ('병역', 1),
#  ('선거구', 1),
#  ('비례대표제', 1),
#  ('기전', 1),
#  ('석방', 1),
#  ('표결', 1),
#  ('청렴', 1),
#  ('직위', 1),
#  ('알선', 1),
#  ('초과', 1),
#  ('명시', 1),
#  ('가부', 1),
#  ('동수', 1),
#  ('부결', 1),
#  ('공표', 1),
#  ('의안', 1),
#  ('폐기', 1),
#  ('환부', 1),
#  ('폐회', 1),
#  ('일부', 1),
#  ('수정', 1),
#  ('반수', 1),
#  ('전과', 1),
#  ('경과', 1),
#  ('전년도', 1),
#  ('사업', 1),
#  ('연한', 1),
#  ('총액', 1),
#  ('차기', 1),
#  ('추가경정예산', 1),
#  ('금액', 1),
#  ('증가', 1),
#  ('비목', 1),
#  ('국채', 1),
#  ('모집', 1),
#  ('조세', 1),
#  ('종목', 1),
#  ('세율', 1),
#  ('원조', 1),
#  ('우호', 1),
#  ('통상항해조약', 1),
#  ('제약', 1),
#  ('군대', 1),
#  ('주류', 1),
#  ('특정', 1),
#  ('사안', 1),
#  ('서류', 1),
#  ('증인', 1),
#  ('증언', 1),
#  ('질문', 1),
#  ('응답', 1),
#  ('징계', 1),
#  ('제명', 1),
#  ('정지', 1),
#  ('공직', 1),
#  ('사상', 1),
#  ('원수', 1),
#  ('대표', 1),
#  ('수호', 1),
#  ('책무', 1),
#  ('성실', 1),
#  ('수반', 1),
#  ('득표자', 1),
#  ('이상인', 1),
#  ('다수표', 1),
#  ('득표수', 1),
#  ('총수', 1),
#  ('당선', 1),
#  ('피선거권', 1),
#  ('선거일', 1),
#  ('사망', 1),
#  ('취임', 1),
#  ('즈음', 1),
#  ('직책', 1),
#  ('사고', 1),
#  ('순서', 1),
#  ('대행', 1),
#  ('사절', 1),
#  ('신임', 1),
#  ('접수', 1),
#  ('통수', 1),
#  ('구체', 1),
#  ('천재', 1),
#  ('위기', 1),
#  ('여유', 1),
#  ('최소한', 1),
#  ('교전', 1),
#  ('상태', 1),
#  ('하기', 1),
#  ('그때', 1),
#  ('폐지', 1),
#  ('회복', 1),
#  ('전시', 1),
#  ('사변', 1),
#  ('비상사태', 1),
#  ('병력', 1),
#  ('경비계엄', 1),
#  ('통고', 1),
#  ('서한', 1),
#  ('표시', 1),
#  ('국법', 1),
#  ('부서', 1),
#  ('공사', 1),
#  ('내란', 1),
#  ('재직', 1),
#  ('전직', 1),
#  ('예우', 1),
#  ('행정부', 1),
#  ('통할', 1),
#  ('구성원', 1),
#  ('국유재산', 1),
#  ('부간', 1),
#  ('획정', 1),
#  ('정부안', 1),
#  ('권한의 위임', 1),
#  ('배정', 1),
#  ('평가', 1),
#  ('분석', 1),
#  ('회부', 1),
#  ('검찰', 1),
#  ('합동', 1),
#  ('참모', 1),
#  ('참모총장', 1),
#  ('국립', 1),
#  ('대학교', 1),
#  ('대사', 1),
#  ('국영', 1),
#  ('관리자', 1),
#  ('국내', 1),
#  ('주재', 1),
#  ('평화통일', 1),
#  ('소관', 1),
#  ('직권', 1),
#  ('감찰', 1),
#  ('소속', 1),
#  ('년대', 1),
#  ('결과', 1),
#  ('대상', 1),
#  ('정년', 1),
#  ('징계처분', 1),
#  ('정직', 1),
#  ('감봉', 1),
#  ('심신', 1),
#  ('장해', 1),
#  ('퇴직', 1),
#  ('최종', 1),
#  ('전심', 1),
#  ('준용', 1),
#  ('소송', 1),
#  ('방해', 1),
#  ('풍속', 1),
#  ('특별법', 1),
#  ('상고심', 1),
#  ('하의', 1),
#  ('간첩죄', 1),
#  ('단심', 1),
#  ('사형', 1),
#  ('관장', 1),
#  ('쟁의', 1),
#  ('인용', 1),
#  ('공정', 1),
#  ('위원장', 1),
#  ('호선', 1),
#  ('명부', 1),
#  ('작성', 1),
#  ('주민', 1),
#  ('종류', 1),
#  ('장의', 1),
#  ('대한민국의 경제', 1),
#  ('창의', 1),
#  ('존중', 1),
#  ('성장', 1),
#  ('소득', 1),
#  ('분배', 1),
#  ('시장', 1),
#  ('지배', 1),
#  ('경제력', 1),
#  ('방지', 1),
#  ('주체', 1),
#  ('민주화', 1),
#  ('광물', 1),
#  ('지하자원', 1),
#  ('수산', 1),
#  ('수력', 1),
#  ('자연력', 1),
#  ('채취', 1),
#  ('특허', 1),
#  ('경자', 1),
#  ('유전', 1),
#  ('소작', 1),
#  ('금지', 1),
#  ('생산성', 1),
#  ('제고', 1),
#  ('합리', 1),
#  ('사정', 1),
#  ('임대차', 1),
#  ('위탁', 1),
#  ('모두', 1),
#  ('생산', 1),
#  ('기반', 1),
#  ('효율', 1),
#  ('어업', 1),
#  ('어촌', 1),
#  ('종합', 1),
#  ('지원', 1),
#  ('농수산물', 1),
#  ('수급', 1),
#  ('유통', 1),
#  ('개선', 1),
#  ('가격', 1),
#  ('도모', 1),
#  ('자조', 1),
#  ('소비', 1),
#  ('계도', 1),
#  ('생산품', 1),
#  ('품질', 1),
#  ('촉구', 1),
#  ('소비자보호', 1),
#  ('무역', 1),
#  ('사영', 1),
#  ('국유', 1),
#  ('공유', 1),
#  ('통제', 1),
#  ('혁신', 1),
#  ('정보', 1),
#  ('인력', 1),
#  ('표준', 1),
#  ('확립', 1),
#  ('기구', 1),
#  ('연장', 1),
#  ('공고', 1),
#  ('투표자', 1),
#  ('보기', 1),
#  ('2월 25일', 1),
#  ('준비', 1),
#  ('공포일', 1),
#  ('6월', 1),
#  ('선거후', 1),
#  ('임원', 1),
#  ('임명권자', 1),
#  ('감사원장', 1),
#  ('전임자', 1),
#  ('판사', 1),
#  ('단서', 1),
#  ('적용', 1),
#  ('지속', 1),
#  ('존속', 1)]

# %%
import pandas as pd
law_df = pd.DataFrame(word_cnt, columns=['단어','빈도수'])
law_df.head()
# Out:
#     단어  빈도수
# 0   법률  128
# 1  대통령   84
# 2   국가   70
# 3   국회   69
# 4   국민   67

# %%
law_df.tail()
# Out:
#      단어  빈도수
# 829  판사    1
# 830  단서    1
# 831  적용    1
# 832  지속    1
# 833  존속    1

# %%
# 5회이상 출현한 단어들만 조회
df = law_df.loc[law_df['빈도수']>5]
df.tail()
# Out:
#       단어  빈도수
# 118  감사원    6
# 119   결정    6
# 120   중임    6
# 121   제청    6
# 122   당시    6

# %%
df.shape
# Out:
# (123, 2)

# %% [markdown]
# ## wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

font = 'c:/Windows/Fonts/malgun.ttf'
wc = WordCloud(
                max_words=100,
                font_path=font,
                min_font_size=1,
                max_font_size=50,
                relative_scaling = 0.2, # 0 ~ 1, 1: 2배 빈도면 폰트크기가 2배    
                background_color='white',
#                 width=600,
#                 height=400
               )
word_cloud = wc.generate_from_frequencies(fd)

# %%
plt.figure(figsize=(15,15))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # TODO
# - news_text.txt 를 읽어 KoNLPy와 NLTK를 이용해 문서 분석
#     - 명사단위로 토큰화
# - 단어 빈도수 DataFrame 생성
# - 가장 많이 나온 10개 단어 선 그래프 작성
# - 가장 많이 나온 3개 단어의 문서내 분포 그래프 작성
# - wordcloud

# %%
with open('news_text.txt', encoding='UTF-8') as f:
    news_txt = f.read()
    
news_txt[:100]
# Out:
# '내년에 지구저궤도에 쏴올리는 수천 개의 인공위성 때문에 밤하늘이 가려져 천문학 연구에 방해가 될 것이라는 우려가 나왔다. \n데이브 클레멘츠 영국 임페리얼칼리지런던 천체물리학과 교수'

# %%
# 토큰화 - 명사
from konlpy.tag import Komoran
komoran = Komoran()
nouns = komoran.nouns(news_txt)
len(nouns)
# Out:
# 305

# %%
print(nouns[:20])
# Out:
# ['내년', '지구', '궤도', '개', '인공위성', '때문', '밤하늘', '천문학', '연구', '방해', '것', '우려', '데이브', '클레멘츠', '영국', '임페리얼', '칼리지', '런던', '천체물리학', '교수']

# %%
from nltk import Text

text = Text(nouns, name='뉴스')
text
# Out:
# <Text: 뉴스>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,7))
text.plot(10)

# %%
plt.figure(figsize=(7,7))
text.dispersion_plot(['인공위성', '관측', '것'])

# %%
fd = text.vocab()
fd
# Out:
# FreqDist({'인공위성': 13, '관측': 12, '것': 10, '수': 9, '개': 8, '천체': 8, '망원경': 6, '있다': 6, '우주': 6, '방해': 5, ...})

# %%
fd.B(), fd.N(), fd.max(), fd.get(fd.max()), fd.freq(fd.max())
# Out:
# (158, 305, '인공위성', 13, 0.04262295081967213)

# %%
import pandas as pd
freq_df = pd.DataFrame(fd.most_common(), columns=['단어','빈도수'])
freq_df.to_csv('news_word_freq.csv', index=False)
freq_df.head(10)
# Out:
#      단어  빈도수
# 0  인공위성   13
# 1    관측   12
# 2     것   10
# 3     수    9
# 4     개    8
# 5    천체    8
# 6   망원경    6
# 7    있다    6
# 8    우주    6
# 9    방해    5

# %%
wc = WordCloud(font_path=font, 
               max_font_size=50,
               min_font_size=1,
               relative_scaling=0.5)

word_cloud = wc.generate_from_frequencies(fd)

# %%
plt.figure(figsize=(15,7))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()
